# %%
from tensorflow import keras

from src.models import Model_ENB7_X2
from src.utils import show_keras_model

# %%
# S = (224, 224, 3)

# i1 = keras.layers.Input(shape=S)
# i2 = keras.layers.Input(shape=S)

# b = keras.applications.EfficientNetB0(
#     include_top=False,
#     weights=None,
#     classes=5,
# )

# x1 = b(i1)
# x2 = b(i2)

# x1 = keras.layers.GlobalAveragePooling2D()(x1)
# x2 = keras.layers.GlobalAveragePooling2D()(x2)

# x1 = keras.layers.BatchNormalization()(x1)
# x2 = keras.layers.BatchNormalization()(x2)

# x = keras.layers.Concatenate()([x1, x2])

# m = keras.Model(inputs=[i1, i2], outputs=[x])

# show_keras_model(m)

# %%
mb = Model_ENB7_X2(n_classes=6)

# %%
m = mb.create()
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.

# %%
show_keras_model(m)

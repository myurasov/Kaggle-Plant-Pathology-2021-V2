# %%
import efficientnet.tfkeras as efn 
from tensorflow import keras

p = '/app/_data/efficientnet-l2_noisy-student_notop.h5'

model = efn.EfficientNetL2(
    weights=p,
    include_top=False,
    drop_connect_rate=0,
    input_shape=(800, 800, 3),
)

# %%
model.summary()
# Out:
# Model: "efficientnet-l2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 800, 800, 3) 0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 400, 400, 136 3672        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 400, 400, 136 544         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 400, 400, 136 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# ...

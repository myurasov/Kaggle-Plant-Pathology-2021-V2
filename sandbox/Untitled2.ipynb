# %%
f = ["__pp_2020__.Train_1073.jpg", "8ff160e487b18e1d.jpg"]

# %%
f = ["__pp_2020__.Train_1376.jpg", "ff76e0956021fa50.jpg"]

# %%
f= ['__pp_2020__.Train_1400.jpg', 'f1139381aa27cdb6.jpg']

# %%
from PIL import Image

# %%
Image.open("/app/_data/pp_2020/new_images/" + f[0]).resize((200, 200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F0741583C40>

# %%
Image.open("/app/_data/src/train_images/" + f[1]).resize((200, 200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F0741780FD0>

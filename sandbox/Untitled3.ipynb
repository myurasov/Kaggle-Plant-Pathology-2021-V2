# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/app/_data/pp_2020/train.csv')
df1.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
df2 = pd.read_csv('/app/res/test_20_labeled.csv')
df2 = df2.rename(columns={'image': 'image_id', 'complex': 'multiple_diseases'})
df2 = df2.drop(['Unnamed: 0', 'labels'], axis=1)
df2['image_id'] = list(map(lambda x: x.replace('.jpg', ''), df2['image_id']))
df2.head()
# Out:
#     image_id  multiple_diseases  frog_eye_leaf_spot  healthy  powdery_mildew  \
# 0  Test_1592                  0                   0        0               0
# 1  Test_1089                  1                   0        0               0
# 2  Test_1636                  0                   0        0               0
# 3  Test_1639                  0                   0        0               0
# 4  Test_1641                  0                   0        0               0
#
#    rust  scab
# 0     0     1
# 1     0     1
# 2     1     0
# 3     0     1
# 4     0     1

# %%
df3 = pd.concat([df1, df2])
df3 = df3.fillna(0)
df3
# Out:
#     image_id  healthy  multiple_diseases  rust  scab  frog_eye_leaf_spot  \
# 0    Train_0        0                  0     0     1                 0.0
# 1    Train_1        0                  1     0     0                 0.0
# 2    Train_2        1                  0     0     0                 0.0
# 3    Train_3        0                  0     1     0                 0.0
# 4    Train_4        1                  0     0     0                 0.0
# ..       ...      ...                ...   ...   ...                 ...
# 888  Test_66        0                  0     0     1                 0.0
# 889  Test_70        0                  0     0     1                 0.0
# 890  Test_72        0                  0     0     1                 0.0
# 891  Test_73        0                  0     0     1                 0.0
# 892  Test_74        0                  0     0     1                 0.0
#
#      powdery_mildew
# 0               0.0
# 1               0.0
# 2               0.0
# ...

# %%
df3
# Out:
#     image_id  healthy  multiple_diseases  rust  scab  frog_eye_leaf_spot  \
# 0    Train_0        0                  0     0     1                 NaN
# 1    Train_1        0                  1     0     0                 NaN
# 2    Train_2        1                  0     0     0                 NaN
# 3    Train_3        0                  0     1     0                 NaN
# 4    Train_4        1                  0     0     0                 NaN
# ..       ...      ...                ...   ...   ...                 ...
# 888  Test_66        0                  0     0     1                 0.0
# 889  Test_70        0                  0     0     1                 0.0
# 890  Test_72        0                  0     0     1                 0.0
# 891  Test_73        0                  0     0     1                 0.0
# 892  Test_74        0                  0     0     1                 0.0
#
#      powdery_mildew
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df3.set
# Out:
# Index(['healthy', 'multiple_diseases', 'rust', 'scab', 'frog_eye_leaf_spot',
#        'powdery_mildew'],
#       dtype='object')

# %%
d = pd.read_csv('/app/_data/pp_2020/_train_plus_test.csv', index_col='image_id')

# %%
for ix, r in d.iterrows():
    pass

# %%
ix
# Out:
# 'Test_74'
